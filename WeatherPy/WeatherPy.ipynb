# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Resources/data_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
np.random.seed(111)
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Request the data
url = "http://api.openweathermap.org/data/2.5/weather?"
lat = []
long = []
Max_temp= []
Humidity= []
Cloudiness= []
Wind_speed= []
Country= []
city_info = []
Date= []

# Build query URL
query_url = f"{url}appid={weather_api_key}&units=imperial&q="
# counter to count the number of calls to API
count = 1
# counter to count the number of call sets
sets = 0 


print(f'Beginning Data Retrieval')
print(f'------------------------')
for city in cities:
    try:
        
        print(f'Processing Record {count} of Set {sets} | {city}' )
        response= requests.get(query_url + city).json()
#         pprint(response)
        city_info.append(response['name'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        Max_temp.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        Wind_speed.append(response['wind']['speed'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
       
        
        count = count+1
        sets = sets+1
        time.sleep(1.01)

        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue    



print(f'------------------------')        
print(f'Data Retrieval Complete')  
print(f'------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 0 | khuldabad
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 2 | soe
# Processing Record 4 of Set 3 | atasu
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 5 | bredasdorp
# Processing Record 7 of Set 6 | hobart
# Processing Record 8 of Set 7 | asau
# Processing Record 9 of Set 8 | ahipara
# Processing Record 10 of Set 9 | khatanga
# Processing Record 11 of Set 10 | mataura
# Processing Record 12 of Set 11 | bluff
# Processing Record 13 of Set 12 | dharchula
# Processing Record 14 of Set 13 | arlit
# Processing Record 15 of Set 14 | westport
# Processing Record 16 of Set 15 | victoria
# Processing Record 17 of Set 16 | punta arenas
# Processing Record 18 of Set 17 | saskylakh
# Processing Record 19 of Set 18 | jasper
# Processing Record 20 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 19 | bethel
# Processing Record 21 of Set 20 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 20 | dawei
# Processing Record 22 of Set 21 | thompson
# Processing Record 23 of Set 22 | bengkulu
# Processing Record 24 of Set 23 | buin
# Processing Record 25 of Set 24 | busselton
# Processing Record 26 of Set 25 | khanion tou kokkini
# City not found. Skipping...
# Processing Record 26 of Set 25 | birao
# Processing Record 27 of Set 26 | rikitea
# Processing Record 28 of Set 27 | tiksi
# Processing Record 29 of Set 28 | hilo
# Processing Record 30 of Set 29 | padang
# Processing Record 31 of Set 30 | chinhoyi
# Processing Record 32 of Set 31 | tholos
# Processing Record 33 of Set 32 | jamestown
# Processing Record 34 of Set 33 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 33 | avera
# Processing Record 35 of Set 34 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 34 | ilulissat
# Processing Record 36 of Set 35 | shitkino
# Processing Record 37 of Set 36 | cherskiy
# Processing Record 38 of Set 37 | upernavik
# Processing Record 39 of Set 38 | sitka
# Processing Record 40 of Set 39 | polewali
# Processing Record 41 of Set 40 | machinga
# Processing Record 42 of Set 41 | geraldton
# Processing Record 43 of Set 42 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 42 | port elizabeth
# Processing Record 44 of Set 43 | castro
# Processing Record 45 of Set 44 | itarema
# Processing Record 46 of Set 45 | cape town
# Processing Record 47 of Set 46 | avarua
# Processing Record 48 of Set 47 | torbay
# Processing Record 49 of Set 48 | nisia floresta
# Processing Record 50 of Set 49 | pithiviers
# Processing Record 51 of Set 50 | zabol
# Processing Record 52 of Set 51 | atuona
# Processing Record 53 of Set 52 | ponta do sol
# Processing Record 54 of Set 53 | buala
# Processing Record 55 of Set 54 | dikson
# Processing Record 56 of Set 55 | east london
# Processing Record 57 of Set 56 | viligili
# City not found. Skipping...
# Processing Record 57 of Set 56 | khorramabad
# Processing Record 58 of Set 57 | pangnirtung
# Processing Record 59 of Set 58 | omboue
# Processing Record 60 of Set 59 | kieta
# Processing Record 61 of Set 60 | ushuaia
# Processing Record 62 of Set 61 | new norfolk
# Processing Record 63 of Set 62 | barentsburg
# City not found. Skipping...
# Processing Record 63 of Set 62 | jahrom
# City not found. Skipping...
# Processing Record 63 of Set 62 | yellowknife
# Processing Record 64 of Set 63 | zyryanka
# Processing Record 65 of Set 64 | fukue
# Processing Record 66 of Set 65 | kastamonu
# Processing Record 67 of Set 66 | santa fe
# Processing Record 68 of Set 67 | stoyba
# City not found. Skipping...
# Processing Record 68 of Set 67 | amderma
# City not found. Skipping...
# Processing Record 68 of Set 67 | tuktoyaktuk
# Processing Record 69 of Set 68 | pacific grove
# Processing Record 70 of Set 69 | itoman
# Processing Record 71 of Set 70 | klaksvik
# Processing Record 72 of Set 71 | clocolan
# Processing Record 73 of Set 72 | gezing
# Processing Record 74 of Set 73 | nizhneyansk
# City not found. Skipping...
# Processing Record 74 of Set 73 | manyana
# Processing Record 75 of Set 74 | krasnotorka
# Processing Record 76 of Set 75 | stokmarknes
# Processing Record 77 of Set 76 | naze
# Processing Record 78 of Set 77 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 78 of Set 77 | jasidih
# Processing Record 79 of Set 78 | lolua
# City not found. Skipping...
# Processing Record 79 of Set 78 | kloulklubed
# Processing Record 80 of Set 79 | jijiang
# Processing Record 81 of Set 80 | puerto ayora
# Processing Record 82 of Set 81 | alotau
# City not found. Skipping...
# Processing Record 82 of Set 81 | ascension
# Processing Record 83 of Set 82 | arraial do cabo
# Processing Record 84 of Set 83 | luderitz
# Processing Record 85 of Set 84 | pevek
# Processing Record 86 of Set 85 | vaini
# Processing Record 87 of Set 86 | marsa matruh
# Processing Record 88 of Set 87 | la ronge
# Processing Record 89 of Set 88 | tulsa
# Processing Record 90 of Set 89 | kapaa
# Processing Record 91 of Set 90 | grand gaube
# Processing Record 92 of Set 91 | kruisfontein
# Processing Record 93 of Set 92 | camacari
# Processing Record 94 of Set 93 | ust-maya
# Processing Record 95 of Set 94 | kodiak
# Processing Record 96 of Set 95 | sakakah
# Processing Record 97 of Set 96 | nikolskoye
# Processing Record 98 of Set 97 | calbuco
# Processing Record 99 of Set 98 | tommot
# Processing Record 100 of Set 99 | rungata
# City not found. Skipping...
# Processing Record 100 of Set 99 | barrow
# Processing Record 101 of Set 100 | yeniseysk
# Processing Record 102 of Set 101 | sorland
# Processing Record 103 of Set 102 | belyy yar
# Processing Record 104 of Set 103 | port alfred
# Processing Record 105 of Set 104 | horki
# Processing Record 106 of Set 105 | camana
# Processing Record 107 of Set 106 | longyearbyen
# Processing Record 108 of Set 107 | puerto del rosario
# Processing Record 109 of Set 108 | rorvik
# Processing Record 110 of Set 109 | ancud
# Processing Record 111 of Set 110 | souillac
# Processing Record 112 of Set 111 | whitianga
# Processing Record 113 of Set 112 | port hardy
# Processing Record 114 of Set 113 | vila franca do campo
# Processing Record 115 of Set 114 | yangambi
# Processing Record 116 of Set 115 | esperance
# Processing Record 117 of Set 116 | seymchan
# Processing Record 118 of Set 117 | butaritari
# Processing Record 119 of Set 118 | west wendover
# Processing Record 120 of Set 119 | lalsk
# Processing Record 121 of Set 120 | campos belos
# Processing Record 122 of Set 121 | high level
# Processing Record 123 of Set 122 | tasiilaq
# Processing Record 124 of Set 123 | urumqi
# Processing Record 125 of Set 124 | havoysund
# Processing Record 126 of Set 125 | marcona
# City not found. Skipping...
# Processing Record 126 of Set 125 | kundiawa
# Processing Record 127 of Set 126 | usinsk
# Processing Record 128 of Set 127 | varberg
# Processing Record 129 of Set 128 | teknaf
# Processing Record 130 of Set 129 | mersing
# Processing Record 131 of Set 130 | oster
# Processing Record 132 of Set 131 | bentiu
# Processing Record 133 of Set 132 | nabire
# Processing Record 134 of Set 133 | karamea
# City not found. Skipping...
# Processing Record 134 of Set 133 | ekibastuz
# Processing Record 135 of Set 134 | novolvovsk
# City not found. Skipping...
# Processing Record 135 of Set 134 | georgetown
# Processing Record 136 of Set 135 | port moresby
# Processing Record 137 of Set 136 | dalbandin
# Processing Record 138 of Set 137 | san patricio
# Processing Record 139 of Set 138 | puerto madero
# Processing Record 140 of Set 139 | simpang
# Processing Record 141 of Set 140 | praia da vitoria
# Processing Record 142 of Set 141 | nanortalik
# Processing Record 143 of Set 142 | norman wells
# Processing Record 144 of Set 143 | dalvik
# Processing Record 145 of Set 144 | fortuna
# Processing Record 146 of Set 145 | muroto
# Processing Record 147 of Set 146 | tombouctou
# Processing Record 148 of Set 147 | la asuncion
# Processing Record 149 of Set 148 | pathanamthitta
# Processing Record 150 of Set 149 | havelock
# Processing Record 151 of Set 150 | markala
# Processing Record 152 of Set 151 | mar del plata
# Processing Record 153 of Set 152 | margate
# Processing Record 154 of Set 153 | mayumba
# Processing Record 155 of Set 154 | namibe
# Processing Record 156 of Set 155 | charters towers
# Processing Record 157 of Set 156 | seminole
# Processing Record 158 of Set 157 | tabuk
# Processing Record 159 of Set 158 | hami
# Processing Record 160 of Set 159 | rio grande
# Processing Record 161 of Set 160 | mahebourg
# Processing Record 162 of Set 161 | bukama
# Processing Record 163 of Set 162 | rzhev
# Processing Record 164 of Set 163 | lazaro cardenas
# Processing Record 165 of Set 164 | morondava
# Processing Record 166 of Set 165 | novikovo
# Processing Record 167 of Set 166 | mino
# Processing Record 168 of Set 167 | umzimvubu
# City not found. Skipping...
# Processing Record 168 of Set 167 | comodoro rivadavia
# Processing Record 169 of Set 168 | zhangjiakou
# Processing Record 170 of Set 169 | mollendo
# Processing Record 171 of Set 170 | sortavala
# Processing Record 172 of Set 171 | lima
# Processing Record 173 of Set 172 | faanui
# Processing Record 174 of Set 173 | calama
# Processing Record 175 of Set 174 | hithadhoo
# Processing Record 176 of Set 175 | lieksa
# Processing Record 177 of Set 176 | matameye
# City not found. Skipping...
# Processing Record 177 of Set 176 | satitoa
# City not found. Skipping...
# Processing Record 177 of Set 176 | novobiryusinskiy
# Processing Record 178 of Set 177 | bangassou
# Processing Record 179 of Set 178 | bowen
# Processing Record 180 of Set 179 | chicama
# Processing Record 181 of Set 180 | venice
# Processing Record 182 of Set 181 | kathu
# Processing Record 183 of Set 182 | ribeira grande
# Processing Record 184 of Set 183 | jalu
# Processing Record 185 of Set 184 | novobirilyussy
# Processing Record 186 of Set 185 | alberton
# Processing Record 187 of Set 186 | harper
# Processing Record 188 of Set 187 | kalabo
# Processing Record 189 of Set 188 | carnarvon
# Processing Record 190 of Set 189 | yumen
# Processing Record 191 of Set 190 | kirakira
# Processing Record 192 of Set 191 | golden
# Processing Record 193 of Set 192 | qaqortoq
# Processing Record 194 of Set 193 | lorengau
# Processing Record 195 of Set 194 | mantua
# Processing Record 196 of Set 195 | middelburg
# Processing Record 197 of Set 196 | sioux lookout
# Processing Record 198 of Set 197 | chapais
# Processing Record 199 of Set 198 | belushya guba
# City not found. Skipping...
# Processing Record 199 of Set 198 | killybegs
# Processing Record 200 of Set 199 | halalo
# City not found. Skipping...
# Processing Record 200 of Set 199 | saint george
# Processing Record 201 of Set 200 | bogorodskoye
# Processing Record 202 of Set 201 | east hampton
# Processing Record 203 of Set 202 | pimentel
# Processing Record 204 of Set 203 | madera
# Processing Record 205 of Set 204 | tautira
# Processing Record 206 of Set 205 | brigg
# Processing Record 207 of Set 206 | hermanus
# Processing Record 208 of Set 207 | abha
# Processing Record 209 of Set 208 | qaanaaq
# Processing Record 210 of Set 209 | laukaa
# Processing Record 211 of Set 210 | tubruq
# City not found. Skipping...
# Processing Record 211 of Set 210 | baruun-urt
# Processing Record 212 of Set 211 | san nicolas
# Processing Record 213 of Set 212 | cidreira
# Processing Record 214 of Set 213 | galle
# Processing Record 215 of Set 214 | kyra
# Processing Record 216 of Set 215 | mujiayingzi
# Processing Record 217 of Set 216 | xushan
# Processing Record 218 of Set 217 | salo
# Processing Record 219 of Set 218 | pahrump
# Processing Record 220 of Set 219 | banda aceh
# Processing Record 221 of Set 220 | king city
# Processing Record 222 of Set 221 | port macquarie
# Processing Record 223 of Set 222 | boa vista
# Processing Record 224 of Set 223 | bahia honda
# Processing Record 225 of Set 224 | payao
# Processing Record 226 of Set 225 | indramayu
# Processing Record 227 of Set 226 | puerto ayacucho
# Processing Record 228 of Set 227 | north bend
# Processing Record 229 of Set 228 | bulawayo
# Processing Record 230 of Set 229 | lucea
# Processing Record 231 of Set 230 | vrangel
# Processing Record 232 of Set 231 | farafangana
# Processing Record 233 of Set 232 | dumai
# Processing Record 234 of Set 233 | bubaque
# Processing Record 235 of Set 234 | passos
# Processing Record 236 of Set 235 | guiyang
# Processing Record 237 of Set 236 | valley city
# Processing Record 238 of Set 237 | rundu
# Processing Record 239 of Set 238 | half moon bay
# Processing Record 240 of Set 239 | mount gambier
# Processing Record 241 of Set 240 | yulara
# Processing Record 242 of Set 241 | namatanai
# Processing Record 243 of Set 242 | high rock
# Processing Record 244 of Set 243 | burnie
# Processing Record 245 of Set 244 | itupiranga
# Processing Record 246 of Set 245 | bathsheba
# Processing Record 247 of Set 246 | tonneins
# Processing Record 248 of Set 247 | muriwai beach
# Processing Record 249 of Set 248 | vanavara
# Processing Record 250 of Set 249 | temaraia
# City not found. Skipping...
# Processing Record 250 of Set 249 | sao filipe
# Processing Record 251 of Set 250 | kroonstad
# Processing Record 252 of Set 251 | vila do maio
# Processing Record 253 of Set 252 | kampong cham
# Processing Record 254 of Set 253 | henties bay
# Processing Record 255 of Set 254 | codrington
# Processing Record 256 of Set 255 | harnosand
# Processing Record 257 of Set 256 | havre-saint-pierre
# Processing Record 258 of Set 257 | waw
# Processing Record 259 of Set 258 | merauke
# Processing Record 260 of Set 259 | ciudad guayana
# Processing Record 261 of Set 260 | ushtobe
# Processing Record 262 of Set 261 | saint-pierre
# Processing Record 263 of Set 262 | karakose
# City not found. Skipping...
# Processing Record 263 of Set 262 | kaitangata
# Processing Record 264 of Set 263 | kambove
# Processing Record 265 of Set 264 | puri
# Processing Record 266 of Set 265 | bambanglipuro
# Processing Record 267 of Set 266 | lillooet
# Processing Record 268 of Set 267 | makushino
# Processing Record 269 of Set 268 | concepcion del oro
# Processing Record 270 of Set 269 | okhotsk
# Processing Record 271 of Set 270 | hamilton
# Processing Record 272 of Set 271 | tual
# Processing Record 273 of Set 272 | bac lieu
# Processing Record 274 of Set 273 | aksarka
# Processing Record 275 of Set 274 | plettenberg bay
# Processing Record 276 of Set 275 | isangel
# Processing Record 277 of Set 276 | alyangula
# Processing Record 278 of Set 277 | umm lajj
# Processing Record 279 of Set 278 | sao joao da barra
# Processing Record 280 of Set 279 | gorele
# Processing Record 281 of Set 280 | akdepe
# Processing Record 282 of Set 281 | provideniya
# Processing Record 283 of Set 282 | holme
# Processing Record 284 of Set 283 | iquique
# Processing Record 285 of Set 284 | calvinia
# Processing Record 286 of Set 285 | raudeberg
# Processing Record 287 of Set 286 | ambodifototra
# City not found. Skipping...
# Processing Record 287 of Set 286 | tezu
# Processing Record 288 of Set 287 | volchikha
# Processing Record 289 of Set 288 | kollumerland
# City not found. Skipping...
# Processing Record 289 of Set 288 | shimoda
# Processing Record 290 of Set 289 | alofi
# Processing Record 291 of Set 290 | zabaykalsk
# Processing Record 292 of Set 291 | tsihombe
# City not found. Skipping...
# Processing Record 292 of Set 291 | takoradi
# Processing Record 293 of Set 292 | nouakchott
# Processing Record 294 of Set 293 | chipata
# Processing Record 295 of Set 294 | solenzo
# Processing Record 296 of Set 295 | luanda
# Processing Record 297 of Set 296 | gaziantep
# Processing Record 298 of Set 297 | demba
# Processing Record 299 of Set 298 | katghora
# Processing Record 300 of Set 299 | fuyang
# Processing Record 301 of Set 300 | zhangye
# Processing Record 302 of Set 301 | lata
# Processing Record 303 of Set 302 | san andres
# Processing Record 304 of Set 303 | carauari
# Processing Record 305 of Set 304 | vostok
# Processing Record 306 of Set 305 | dingle
# Processing Record 307 of Set 306 | may pen
# Processing Record 308 of Set 307 | krasnoselkup
# Processing Record 309 of Set 308 | katsuura
# Processing Record 310 of Set 309 | nelson bay
# Processing Record 311 of Set 310 | dengzhou
# Processing Record 312 of Set 311 | belomorsk
# Processing Record 313 of Set 312 | olafsvik
# Processing Record 314 of Set 313 | petropavlovsk-kamchatskiy
# Processing Record 315 of Set 314 | fethiye
# Processing Record 316 of Set 315 | conceicao da barra
# Processing Record 317 of Set 316 | bongandanga
# Processing Record 318 of Set 317 | saleaula
# City not found. Skipping...
# Processing Record 318 of Set 317 | cabo san lucas
# Processing Record 319 of Set 318 | skalistyy
# City not found. Skipping...
# Processing Record 319 of Set 318 | vitim
# Processing Record 320 of Set 319 | karratha
# Processing Record 321 of Set 320 | turukhansk
# Processing Record 322 of Set 321 | bolungarvik
# City not found. Skipping...
# Processing Record 322 of Set 321 | los llanos de aridane
# Processing Record 323 of Set 322 | baghmara
# Processing Record 324 of Set 323 | mpika
# Processing Record 325 of Set 324 | aklavik
# Processing Record 326 of Set 325 | nanma
# Processing Record 327 of Set 326 | ceres
# Processing Record 328 of Set 327 | paamiut
# Processing Record 329 of Set 328 | grand falls
# Processing Record 330 of Set 329 | lengshuitan
# Processing Record 331 of Set 330 | coquimbo
# Processing Record 332 of Set 331 | flinders
# Processing Record 333 of Set 332 | baykit
# Processing Record 334 of Set 333 | sarkand
# Processing Record 335 of Set 334 | nome
# Processing Record 336 of Set 335 | hambantota
# Processing Record 337 of Set 336 | necochea
# Processing Record 338 of Set 337 | yamada
# Processing Record 339 of Set 338 | tawkar
# City not found. Skipping...
# Processing Record 339 of Set 338 | gizo
# Processing Record 340 of Set 339 | san vicente
# Processing Record 341 of Set 340 | ruangwa
# Processing Record 342 of Set 341 | keti bandar
# Processing Record 343 of Set 342 | aitape
# Processing Record 344 of Set 343 | san juan de los morros
# Processing Record 345 of Set 344 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 345 of Set 344 | beloha
# Processing Record 346 of Set 345 | erzin
# Processing Record 347 of Set 346 | paita
# Processing Record 348 of Set 347 | bogale
# Processing Record 349 of Set 348 | warri
# Processing Record 350 of Set 349 | aviles
# Processing Record 351 of Set 350 | sainte-maxime
# Processing Record 352 of Set 351 | eyrarbakki
# Processing Record 353 of Set 352 | touros
# Processing Record 354 of Set 353 | sharan
# Processing Record 355 of Set 354 | miri
# Processing Record 356 of Set 355 | ariquemes
# Processing Record 357 of Set 356 | izumo
# Processing Record 358 of Set 357 | worland
# Processing Record 359 of Set 358 | rawson
# Processing Record 360 of Set 359 | mabaruma
# Processing Record 361 of Set 360 | fort nelson
# Processing Record 362 of Set 361 | massakory
# Processing Record 363 of Set 362 | marienburg
# Processing Record 364 of Set 363 | balykshi
# Processing Record 365 of Set 364 | maceio
# Processing Record 366 of Set 365 | kudahuvadhoo
# Processing Record 367 of Set 366 | khani
# Processing Record 368 of Set 367 | lamar
# Processing Record 369 of Set 368 | banff
# Processing Record 370 of Set 369 | saryshagan
# City not found. Skipping...
# Processing Record 370 of Set 369 | tiptur
# Processing Record 371 of Set 370 | clyde river
# Processing Record 372 of Set 371 | uglovskoye
# Processing Record 373 of Set 372 | mincivan
# Processing Record 374 of Set 373 | komsomolskiy
# Processing Record 375 of Set 374 | zelenoborskiy
# Processing Record 376 of Set 375 | rio gallegos
# Processing Record 377 of Set 376 | saint-philippe
# Processing Record 378 of Set 377 | chokurdakh
# Processing Record 379 of Set 378 | mweka
# Processing Record 380 of Set 379 | waldoboro
# Processing Record 381 of Set 380 | moerai
# Processing Record 382 of Set 381 | bambous virieux
# Processing Record 383 of Set 382 | coahuayana
# Processing Record 384 of Set 383 | edd
# Processing Record 385 of Set 384 | moranbah
# Processing Record 386 of Set 385 | ostrovnoy
# Processing Record 387 of Set 386 | morant bay
# Processing Record 388 of Set 387 | cockburn town
# Processing Record 389 of Set 388 | leningradskiy
# Processing Record 390 of Set 389 | san martin
# Processing Record 391 of Set 390 | nizhnevartovsk
# Processing Record 392 of Set 391 | susanville
# Processing Record 393 of Set 392 | kavieng
# Processing Record 394 of Set 393 | owando
# Processing Record 395 of Set 394 | bodden town
# Processing Record 396 of Set 395 | khonuu
# City not found. Skipping...
# Processing Record 396 of Set 395 | lokosovo
# Processing Record 397 of Set 396 | joshimath
# Processing Record 398 of Set 397 | banjarmasin
# Processing Record 399 of Set 398 | kimbe
# Processing Record 400 of Set 399 | airai
# Processing Record 401 of Set 400 | anshun
# Processing Record 402 of Set 401 | kuching
# Processing Record 403 of Set 402 | karaul
# City not found. Skipping...
# Processing Record 403 of Set 402 | onega
# Processing Record 404 of Set 403 | bougouni
# Processing Record 405 of Set 404 | minot
# Processing Record 406 of Set 405 | ambon
# Processing Record 407 of Set 406 | lucapa
# Processing Record 408 of Set 407 | mahibadhoo
# Processing Record 409 of Set 408 | laguna
# Processing Record 410 of Set 409 | mercedes
# Processing Record 411 of Set 410 | kahului
# Processing Record 412 of Set 411 | balabac
# Processing Record 413 of Set 412 | pitea
# Processing Record 414 of Set 413 | utiroa
# City not found. Skipping...
# Processing Record 414 of Set 413 | kasongo
# Processing Record 415 of Set 414 | broome
# Processing Record 416 of Set 415 | tawnat
# City not found. Skipping...
# Processing Record 416 of Set 415 | chuy
# Processing Record 417 of Set 416 | lavrentiya
# Processing Record 418 of Set 417 | kununurra
# Processing Record 419 of Set 418 | samarai
# Processing Record 420 of Set 419 | quatre cocos
# Processing Record 421 of Set 420 | maniitsoq
# Processing Record 422 of Set 421 | semey
# Processing Record 423 of Set 422 | taitung
# Processing Record 424 of Set 423 | tres arroyos
# Processing Record 425 of Set 424 | kaeo
# Processing Record 426 of Set 425 | samusu
# City not found. Skipping...
# Processing Record 426 of Set 425 | mlonggo
# Processing Record 427 of Set 426 | tuatapere
# Processing Record 428 of Set 427 | uusikaupunki
# Processing Record 429 of Set 428 | axim
# Processing Record 430 of Set 429 | lagoa
# Processing Record 431 of Set 430 | priekule
# Processing Record 432 of Set 431 | lakes entrance
# Processing Record 433 of Set 432 | nicolet
# Processing Record 434 of Set 433 | biak
# Processing Record 435 of Set 434 | waingapu
# Processing Record 436 of Set 435 | pangkalanbuun
# Processing Record 437 of Set 436 | nouadhibou
# Processing Record 438 of Set 437 | leh
# Processing Record 439 of Set 438 | meulaboh
# Processing Record 440 of Set 439 | alexandria
# Processing Record 441 of Set 440 | vladeni
# Processing Record 442 of Set 441 | labrea
# Processing Record 443 of Set 442 | vila velha
# Processing Record 444 of Set 443 | highland
# Processing Record 445 of Set 444 | molodizhne
# Processing Record 446 of Set 445 | beira
# Processing Record 447 of Set 446 | caconda
# Processing Record 448 of Set 447 | annau
# Processing Record 449 of Set 448 | tulagi
# Processing Record 450 of Set 449 | sisimiut
# Processing Record 451 of Set 450 | maues
# Processing Record 452 of Set 451 | luba
# Processing Record 453 of Set 452 | vestmannaeyjar
# Processing Record 454 of Set 453 | zheleznodorozhnyy
# Processing Record 455 of Set 454 | vredendal
# Processing Record 456 of Set 455 | carbonia
# Processing Record 457 of Set 456 | port lincoln
# Processing Record 458 of Set 457 | dongzhen
# Processing Record 459 of Set 458 | yining
# Processing Record 460 of Set 459 | ruteng
# Processing Record 461 of Set 460 | jumla
# Processing Record 462 of Set 461 | pisco
# Processing Record 463 of Set 462 | oulu
# Processing Record 464 of Set 463 | ust-tsilma
# Processing Record 465 of Set 464 | san quintin
# Processing Record 466 of Set 465 | kuytun
# Processing Record 467 of Set 466 | batemans bay
# Processing Record 468 of Set 467 | walvis bay
# Processing Record 469 of Set 468 | juazeirinho
# Processing Record 470 of Set 469 | oistins
# Processing Record 471 of Set 470 | pilar
# Processing Record 472 of Set 471 | saint-augustin
# Processing Record 473 of Set 472 | okha
# Processing Record 474 of Set 473 | talnakh
# Processing Record 475 of Set 474 | vao
# Processing Record 476 of Set 475 | alta floresta
# Processing Record 477 of Set 476 | saint-leu
# Processing Record 478 of Set 477 | guerrero negro
# Processing Record 479 of Set 478 | beringovskiy
# Processing Record 480 of Set 479 | sangar
# Processing Record 481 of Set 480 | kushmurun
# Processing Record 482 of Set 481 | niamey
# Processing Record 483 of Set 482 | matara
# Processing Record 484 of Set 483 | oum hadjer
# Processing Record 485 of Set 484 | cayenne
# Processing Record 486 of Set 485 | poltavka
# Processing Record 487 of Set 486 | horasan
# Processing Record 488 of Set 487 | saldanha
# Processing Record 489 of Set 488 | salinopolis
# Processing Record 490 of Set 489 | prestea
# Processing Record 491 of Set 490 | khorixas
# Processing Record 492 of Set 491 | grand forks
# Processing Record 493 of Set 492 | sistranda
# Processing Record 494 of Set 493 | haysville
# Processing Record 495 of Set 494 | talcahuano
# Processing Record 496 of Set 495 | beyneu
# Processing Record 497 of Set 496 | nuuk
# Processing Record 498 of Set 497 | zheshart
# Processing Record 499 of Set 498 | sovetskiy
# Processing Record 500 of Set 499 | narsaq
# Processing Record 501 of Set 500 | inhambane
# Processing Record 502 of Set 501 | richards bay
# Processing Record 503 of Set 502 | misratah
# Processing Record 504 of Set 503 | salalah
# Processing Record 505 of Set 504 | svetlaya
# Processing Record 506 of Set 505 | rivadavia
# Processing Record 507 of Set 506 | tofield
# Processing Record 508 of Set 507 | isla mujeres
# Processing Record 509 of Set 508 | coihaique
# Processing Record 510 of Set 509 | vadso
# Processing Record 511 of Set 510 | moroto
# Processing Record 512 of Set 511 | bonthe
# Processing Record 513 of Set 512 | zhezkazgan
# Processing Record 514 of Set 513 | evensk
# Processing Record 515 of Set 514 | haines junction
# Processing Record 516 of Set 515 | jiuquan
# Processing Record 517 of Set 516 | malartic
# Processing Record 518 of Set 517 | atar
# Processing Record 519 of Set 518 | khasan
# Processing Record 520 of Set 519 | sampit
# Processing Record 521 of Set 520 | severo-kurilsk
# Processing Record 522 of Set 521 | slonim
# Processing Record 523 of Set 522 | muscat
# Processing Record 524 of Set 523 | constitucion
# Processing Record 525 of Set 524 | tarakan
# Processing Record 526 of Set 525 | tamazulapam
# City not found. Skipping...
# Processing Record 526 of Set 525 | manggar
# Processing Record 527 of Set 526 | solnechnyy
# Processing Record 528 of Set 527 | ostersund
# Processing Record 529 of Set 528 | eyl
# Processing Record 530 of Set 529 | noumea
# Processing Record 531 of Set 530 | markova
# Processing Record 532 of Set 531 | abiramam
# Processing Record 533 of Set 532 | tigil
# Processing Record 534 of Set 533 | warqla
# City not found. Skipping...
# Processing Record 534 of Set 533 | sakaiminato
# Processing Record 535 of Set 534 | fairbanks
# Processing Record 536 of Set 535 | asyut
# Processing Record 537 of Set 536 | sarankhola
# Processing Record 538 of Set 537 | alice springs
# Processing Record 539 of Set 538 | neryungri
# Processing Record 540 of Set 539 | port blair
# Processing Record 541 of Set 540 | pagudpud
# Processing Record 542 of Set 541 | ribe
# Processing Record 543 of Set 542 | iqaluit
# Processing Record 544 of Set 543 | broken hill
# Processing Record 545 of Set 544 | le port
# Processing Record 546 of Set 545 | emerald
# Processing Record 547 of Set 546 | tura
# Processing Record 548 of Set 547 | tumannyy
# City not found. Skipping...
# Processing Record 548 of Set 547 | buraydah
# Processing Record 549 of Set 548 | dolbeau
# City not found. Skipping...
# Processing Record 549 of Set 548 | zhigansk
# Processing Record 550 of Set 549 | puerto carreno
# Processing Record 551 of Set 550 | ilo
# Processing Record 552 of Set 551 | chagda
# City not found. Skipping...
# Processing Record 552 of Set 551 | kupang
# Processing Record 553 of Set 552 | panguna
# Processing Record 554 of Set 553 | parfenyevo
# Processing Record 555 of Set 554 | rudbar
# Processing Record 556 of Set 555 | sinnamary
# Processing Record 557 of Set 556 | linkoping
# Processing Record 558 of Set 557 | meyungs
# City not found. Skipping...
# Processing Record 558 of Set 557 | madison
# Processing Record 559 of Set 558 | bahir dar
# Processing Record 560 of Set 559 | zunyi
# Processing Record 561 of Set 560 | lompoc
# Processing Record 562 of Set 561 | lykhivka
# Processing Record 563 of Set 562 | te anau
# Processing Record 564 of Set 563 | korla
# Processing Record 565 of Set 564 | pata
# Processing Record 566 of Set 565 | porto novo
# Processing Record 567 of Set 566 | sinkat
# City not found. Skipping...
# Processing Record 567 of Set 566 | kayerkan
# Processing Record 568 of Set 567 | riyadh
# Processing Record 569 of Set 568 | mattru
# Processing Record 570 of Set 569 | kovdor
# Processing Record 571 of Set 570 | kampong chhnang
# Processing Record 572 of Set 571 | kilakarai
# Processing Record 573 of Set 572 | shellbrook
# Processing Record 574 of Set 573 | lalmohan
# Processing Record 575 of Set 574 | esqueda
# Processing Record 576 of Set 575 | gawler
# Processing Record 577 of Set 576 | lazy
# Processing Record 578 of Set 577 | aksu
# Processing Record 579 of Set 578 | kavaratti
# Processing Record 580 of Set 579 | yaring
# Processing Record 581 of Set 580 | chama
# Processing Record 582 of Set 581 | asfi
# Processing Record 583 of Set 582 | burgersdorp
# Processing Record 584 of Set 583 | takanabe
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Put the information into dataframe

city_df= pd.DataFrame({"City": city_info,
                       "Lat": lat,
                       "Lng": long,
                        "Max Temp": Max_temp,
                        "Humidity": Humidity,
                        "Cloudiness": Cloudiness,
                        "Wind Speed": Wind_speed,
                        "Country": Country,
                         "Date": Date})
city_df.to_csv("../Resources/city_df.csv", header= True)

city_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Khuldābād  20.0500   75.1833     58.73        32          65        6.49
# 1     Albany  42.6001  -73.9662     28.99        63          99        3.00
# 2        Soe  -9.8607  124.2840     72.37        88         100        6.33
# 3      Atasū  48.6814   71.6433     33.13        96         100       30.00
# 4       Lebu -37.6167  -73.6500     60.76        87          54        3.87
#
#   Country        Date
# 0      IN  1612740621
# 1      US  1612740304
# 2      ID  1612740623
# 3      KZ  1612740624
# 4      CL  1612740396

# %%
#delete country, city column
num= city_df.drop(["City", "Country"], axis=1)

#caltulate mean, std, etc
count= num.count()
mean= num.mean()
std=num.std()
minimum= num.min()
maximum= num.max()
lower=num.quantile(0.25)
median= num.quantile(0.5)
upper= num.quantile(0.75)

mean_df= pd.DataFrame({"Count":count,
                      "Mean":mean,
                     "Std":std,
                      "Min":minimum,
                      "25%":lower,
                       "50%":median,
                       "75%": upper,
                     "Max":maximum})
                     
stats=mean_df.transpose()
stats
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# Count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# Mean    19.097476   24.816413   51.571353   71.743151   55.750000    8.883134
# Std     33.487927   88.319402   33.268441   20.391178   38.798718    6.503377
# Min    -54.800000 -175.200000  -45.990000    8.000000    0.000000    0.200000
# 25%     -8.503425  -53.788450   27.705000   61.000000   19.000000    4.197500
# 50%     22.323300   28.849850   62.600000   76.000000   71.000000    7.575000
# 75%     47.989650  101.463400   78.800000   87.000000   92.000000   11.500000
# Max     78.218600  179.316700  100.740000  100.000000  100.000000   47.180000
#
#                Date
# Count  5.840000e+02
# Mean   1.612708e+09
# Std    2.107790e+02
# Min    1.612708e+09
# 25%    1.612708e+09
# 50%    1.612708e+09
# 75%    1.612709e+09
# Max    1.612709e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum_stat = city_df["Humidity"].describe(include = "all")
hum_stat
# Out:
# count    584.000000
# mean      74.724315
# std       18.987159
# min        7.000000
# 25%       66.000000
# 50%       79.000000
# 75%       88.000000
# max      100.000000
# Name: Humidity, dtype: float64

# %%
#  Get the indices of cities that have humidity over 100%.
high_humididy= city_df[city_df["Humidity"]>100].index
high_humididy
# Out:
# Int64Index([], dtype='int64')

# %%
#Calculate outliers

clean_city_data= city_df.drop(high_humididy, inplace=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Scatter plot of Max temperature Vs Latitude
city_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8), edgecolors= "black",
              title="City Latitude vs Max Temperature (02/05/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig("../Images/scatter_tempvslat.png")

# %%
#Scatter plot of  Humidity Vs Latitude
city_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8), edgecolors= "black",
              title="City Latitude vs Humidity (02/05/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig("../Images/scatter_humvslat.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Scatter plot of  cloudiness Vs Latitude
city_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8), edgecolors= "black",
              title="City Latitude vs Cloudiness (02/05/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig("../Images/scatter_cloudvslat.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Scatter plot of  Wind Speed Vs Latitude
city_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8), edgecolors= "black",
              title="City Latitude vs Cloudiness (02/05/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.savefig("../Images/scatter_windvslat.png")

# %% [markdown]
# ## Linear Regression

# %%
#create Northern and Southern temp
north= city_df.loc[city_df["Lat"]>0, :]
south= city_df.loc[city_df["Lat"]<0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = north["Lat"]
y_values = north["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(0,-40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max temp')

print(f"The r-value is:{rvalue}")
plt.show()
plt.savefig("../Images/North_tempvslat.png")
# Out:
# The r-value is:-0.8609613187847768

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = south["Lat"]
y_values = south["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max temp')

print(f"The r-value is:{rvalue}")
plt.show()
plt.savefig("../Images/south_tempvslat.png")
# Out:
# The r-value is:0.5853594090388973

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = north["Lat"]
y_values = north["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

print(f"The r-value is:{rvalue}")
plt.show()
plt.savefig("../Images/North_humivslat.png")
# Out:
# The r-value is:0.2424923787965277

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = south["Lat"]
y_values = south["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(-55,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

print(f"The r-value is:{rvalue}")
plt.show()
plt.savefig("../Images/south_humivslat.png")
# Out:
# The r-value is:0.379969974589483

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = north["Lat"]
y_values = north["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

print(f"The r-value is:{rvalue}")
plt.show()
plt.savefig("../Images/North_cloudvslat.png")
# Out:
# The r-value is:0.12116170512198286

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = south["Lat"]
y_values = south["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(-55,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

print(f"The r-value is:{rvalue}")
plt.show()
plt.savefig("../Images/south_cloudvslat.png")
# Out:
# The r-value is:0.3058266778382681

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = north["Lat"]
y_values = north["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(0,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

print(f"The r-value is:{rvalue}")
plt.show()
plt.savefig("../Images/North_windvslat.png")
# Out:
# The r-value is:0.17710916970781418

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = south["Lat"]
y_values = south["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(' Wind Speed ')

print(f"The r-value is:{rvalue}")
plt.show()
#plt.savefig("Images/south_windvslat.png")
# Out:
# The r-value is:-0.18680037560304774
